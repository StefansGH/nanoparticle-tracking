# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 5))
mpl.rc('image', cmap='gray')

import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims
import trackpy as tp

tp.quiet()  # Turn off progress reports for best performance

# %%
@pims.pipeline
def gray(image):
    return image[:, :, 0]  # Take just the green channel

frames = gray(pims.open('overview/*.png'))

# %% [markdown]
# Detecting particles in one frame:

# %%
f = tp.locate(frames[0], 11, invert=False, minmass=700)
tp.annotate(f, frames[0]);

# %% [markdown]
# Detecting particles in all frames:

# %%
f = tp.batch(frames[:10], 11, minmass=700, invert=False)
f.head(3)
# Out:
#            y           x        mass      size       ecc     signal  raw_mass  \
# 0   5.539611  928.364723  889.089996  2.304217  0.073847  47.178916    2288.0
# 1   6.092576  747.799267  724.960528  2.194903  0.143945  39.869507    1687.0
# 2  10.278276  269.981149  740.243839  1.977204  0.140426  51.165867    1461.0
#
#          ep  frame
# 0  0.002604      0
# 1  0.003534      0
# 2  0.004082      0

# %% [markdown]
# Linking particles in between frames (trajectories):

# %%
t = tp.link(f, 5, memory=3)
t.head(3)
# Out:
#               y           x         mass      size       ecc     signal  \
# 0      5.539611  928.364723   889.089996  2.304217  0.073847  47.178916
# 125  745.509730  137.556757  1229.309786  2.248483  0.181627  69.107145
# 126  747.915347  569.231425  1091.095496  3.255558  0.068394  22.592720
#
#      raw_mass        ep  frame  particle
# 0      2288.0  0.002604      0         0
# 125    2742.0  0.002172      0         1
# 126    5699.0  0.001044      0         2

# %% [markdown]
# Ephemeral trajectories — seen only for a few frames — are usually spurious and never useful. The convenience function filter_stubs keeps only trajectories that last for a given number of frames.

# %%
t1 = tp.filter_stubs(t, 5)
# Compare the number of particles in the unfiltered and filtered data.
print('Before:', t['particle'].nunique())
print('After:', t1['particle'].nunique())
t1.head(3)
# Out:
# Before: 374
# After: 175
#                 y           x         mass      size       ecc     signal  \
# frame
# 0        5.539611  928.364723   889.089996  2.304217  0.073847  47.178916
# 0      745.509730  137.556757  1229.309786  2.248483  0.181627  69.107145
# 0      747.915347  569.231425  1091.095496  3.255558  0.068394  22.592720
#
#        raw_mass        ep  frame  particle
# frame
# 0        2288.0  0.002604      0         0
# 0        2742.0  0.002172      0         1
# 0        5699.0  0.001044      0         2

# %% [markdown]
# Trajectory information of particle #2:

# %%
t1[t1.particle==2]
# Out:
#                 y           x         mass      size       ecc     signal  \
# frame
# 0      747.915347  569.231425  1091.095496  3.255558  0.068394  22.592720
# 1      748.032360  569.444797  1036.058677  3.201760  0.074531  23.666315
# 2      748.928685  573.589675  1197.039387  3.150390  0.113898  30.578973
# 3      748.606172  572.707508  1409.598724  3.071991  0.129046  34.412129
# 4      747.924742  573.099361  1325.697699  3.128106  0.032570  31.300290
# 5      748.453552  574.128415  1435.439527  3.101648  0.089997  35.297693
# 6      748.910936  574.059752  1192.395121  3.170111  0.110316  25.541722
# 7      749.623910  574.253425  1064.222147  3.101139  0.169134  26.506156
# 9      749.991827  576.092236  1150.480766  3.318296  0.130372  21.491760
#
#        raw_mass        ep  frame  particle
# frame
# 0        5699.0  0.001044      0         2
# 1        5270.0  0.001106      1         2
# 2        5954.0  0.000906      2         2
# 3        6544.0  0.000867      3         2
# 4        6462.0  0.000871      4         2
# 5        6972.0  0.000811      5         2
# 6        6075.0  0.000899      6         2
# 7        5527.0  0.000998      7         2
# 9        5864.0  0.000930      9         2

# %%
plt.figure()
tp.plot_traj(t1);

# %% [markdown]
# Compute the mean squared displacement (MSD) of each particle

# %%
im = tp.imsd(t1, 100/285., 50)  # microns per pixel = 100/285., frames per second = 50
im#[2]
# Out:
#                    0          1         2         3         4         6    \
# lag time [s]
# 0.02          0.192519   0.505962  0.380620  0.335946  0.140963  0.336276
# 0.04          0.481315   1.774780  0.722565  0.394066  0.388075  0.894036
# 0.06          0.862650   3.727199  0.777339  0.871641  0.800028  1.336546
# 0.08          1.247910   6.112847  1.155913  2.019331  1.475847  1.448493
# 0.10          1.475752   8.233833  1.861925  4.462048  2.301754  1.727883
# 0.12          1.338964  10.201730  2.599212  4.999677  2.922726  1.758429
# 0.14          1.548134  12.390076  2.187304  4.183872  3.641013  1.221186
# 0.16               NaN  14.129548  5.912952  4.404613  3.850185  0.960033
# 0.18               NaN  12.353588  6.325946  6.386954  3.622997  1.462118
#
#                    8         9         11        12   ...       223       224  \
# lag time [s]                                          ...
# 0.02          0.183918  0.178302  0.493981  0.008040  ...  0.452387  0.232738
# 0.04          0.263079  0.495544  1.031634  0.006130  ...  0.349333  0.539461
# 0.06          0.314813  0.602967  1.455614  0.006638  ...  0.912174  1.609061
# 0.08          0.498535  0.613470  2.111277  0.006674  ...  0.783512  1.823746
# 0.10          0.786376  0.631866  2.664487  0.008014  ...  1.190538  2.566875
# 0.12          0.851783  0.685284  2.066071  0.001869  ...  0.000000       NaN
# 0.14          0.800598  0.944062  3.082120  0.010009  ...  0.239380       NaN
# 0.16          1.041853  1.736876  5.142198  0.008747  ...  0.931916       NaN
# 0.18          0.547605  2.516412  2.488643  0.000017  ...       NaN       NaN
#
#                    225       243       246       248       257       287  \
# lag time [s]
# 0.02          0.366095  0.213319  0.254718  0.261816  0.277291  0.192834
# 0.04          1.102290  0.540782  0.791734  0.529240  0.602632  0.482836
# 0.06          1.812308  0.714586  0.000000  0.912536  0.599204  0.683908
# 0.08          2.272878  0.650147  1.516863  1.427667  0.926231  0.642288
# 0.10          2.110971  0.526676  0.998708  2.024208  0.827462  0.369922
# 0.12          1.767563  0.194455  1.241666  2.262273  0.874442       NaN
# 0.14          2.042564  0.166592  1.419729  2.311444       NaN       NaN
# 0.16          3.239388       NaN       NaN       NaN       NaN       NaN
# 0.18               NaN       NaN       NaN       NaN       NaN       NaN
#
#                    297       310
# lag time [s]
# 0.02          0.743007  0.387662
# 0.04          1.478863  0.550206
# 0.06          3.584628  1.035035
# 0.08          5.907816  1.998013
# 0.10               NaN       NaN
# 0.12               NaN       NaN
# 0.14               NaN       NaN
# 0.16               NaN       NaN
# 0.18               NaN       NaN
#
# [9 rows x 175 columns]
